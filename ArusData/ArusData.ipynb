# %%
import pandas as pd 
import numpy as np
import base64

# %%
POD = pd.read_csv("C:/Users/Lo/ArusData/ProgramOverallData.csv")
TW = pd.read_csv("C:/Users/Lo/ArusData/TintaWorkshop.csv")
A2 = pd.read_csv("C:/Users/Lo/ArusData/A2ii.csv")
Mara = pd.read_csv("C:/Users/Lo/ArusData/MARA.csv")
Sup = pd.read_csv("C:/Users/Lo/ArusData/DRA/DRA-Supplementary.csv")
TTD1 = pd.read_csv("C:/Users/Lo/ArusData/DRA/DRA-TeacherTrainingDay1.csv")
TTD2 = pd.read_csv("C:/Users/Lo/ArusData/DRA/DRA-TeacherTrainingDay2.csv")
DRA = pd.read_csv("C:/Users/Lo/ArusData/DRA/DRA-Program.csv")
HD = pd.read_csv("C:/Users/Lo/ArusData/DRA/DRA-HackathonDay.csv")
FBDA = pd.read_csv("C:/Users/Lo/ArusData/FBD/FBDDataAll.csv")
FIYC12 = pd.read_csv("C:/Users/Lo/ArusData/FIYC/FIYC1&2.csv")
FIYC34 = pd.read_csv("C:/Users/Lo/ArusData/FIYC/FIYC3&4.csv")
FIYC = pd.read_csv("C:/Users/Lo/ArusData/FIYC/FIYC.csv")
AOT1 = pd.read_csv("C:/Users/Lo/ArusData/Agents of Tech/(AOT)BengkelCutiSekolah.csv")
AOT2 = pd.read_csv("C:/Users/Lo/ArusData/Agents of Tech/(AOT)BorangMaklumBalasBengkelCutiSekolah.csv")
AOT3 = pd.read_csv("C:/Users/Lo/ArusData/Agents of Tech/BengkelAOT.csv")
AOT4 = pd.read_csv("C:/Users/Lo/ArusData/Agents of Tech/BengkelEdidik(AOT).csv")
AOT5 = pd.read_csv("C:/Users/Lo/ArusData/Agents of Tech/BengkelPersediaanPertandingan(AOT).csv")
PM = pd.read_csv("C:/Users/Lo/ArusData/GCK/PM.csv")
Ed = pd.read_csv("C:/Users/Lo/ArusData/GCK/Edidik.csv")
GCK = pd.read_csv("C:/Users/Lo/ArusData/GCK/GCK.csv")
GCEDPerak = pd.read_csv("C:/Users/Lo/ArusData/GCED/GCEDJPN-Perak.csv")
GCEDPerlis = pd.read_csv("C:/Users/Lo/ArusData/GCED/GCEDJPN-Perlis.csv")
GCEDPerlis1 = pd.read_csv("C:/Users/Lo/ArusData/GCED/GCEDJPN-Perlis1.csv")
GCEDPerlis2 = pd.read_csv("C:/Users/Lo/ArusData/GCED/GCEDJPN-Perlis2.csv")
GCEDPerlis3 = pd.read_csv("C:/Users/Lo/ArusData/GCED/GCEDJPN-Perlis3.csv")
GCEDPerlisAll = pd.read_csv("C:/Users/Lo/ArusData/GCED/GCEDPerlisAll.csv")
GCEDAll = pd.read_csv("C:/Users/Lo/ArusData/GCED/GCEDAll.csv")
JMC1 = pd.read_csv("C:/Users/Lo/ArusData/JMC/JMC-Exit-Ticket.csv")
JMC2 = pd.read_csv("C:/Users/Lo/ArusData/JMC/eJMC-Exit-Ticket-B2.csv")
JMC3 = pd.read_csv("C:/Users/Lo/ArusData/JMC/JMC-Holiday-Workshop.csv")
JMC4 = pd.read_csv("C:/Users/Lo/ArusData/JMC/JMC-Sep-Hackathon.csv")
JMC5 = pd.read_csv("C:/Users/Lo/ArusData/JMC/JMC-Trial-Class.csv")
JMCAll = pd.read_csv("C:/Users/Lo/ArusData/JMC/JMCAll.csv")

# %%
New_CName=[]
DN=[]
for i in POD:
    #print(i)
    New_CName.append(i)

    
for x in JMCAll:
    y=0
    for i in New_CName:
        if x==i:
            y=1
            break
    if(y==0):
        New_CName.append(x)
        print(x)
 

    
print(len(New_CName))  
#print(New_CName)

#for i in New_CName:
    #for x in Kedah3:
       # if i!=x:
           # New_CName.append(x)            
#print(len(Perlis2.columns))
#print(len(New_CName))
         
        
#display(GMIL1)
#display(Kedah1)
# Out:
# Lesson
# I accomplished today's learning objectives
# I am comfortable learning by myself
# The instruction used is simple enough for me to understand
# The arrangement of the lesson flow helps my learning
# The video recordings are helpful.
# sa
# General comments/questions/feedback/things you wish the instructor to know about this lesson?
# Which programme are you in?
# Did you join the session on Wednesday (15th September 2021)?
# General comments/questions/feedback/things you wish the instructor to know about this session?
# Did you join any of the previous session?
# Parent's name:
# Parent's contact number
# What do you like about this trial class? How can this trial class / programme be further? improved?
# I want to confirm my registration for Arus Tech Programmes NOW.
# I want to sign-up for this programme:
# Student email:
# Would you mind sharing with us your concerns?
# Additional comments or questions for us:
# 259

# %%
new_df = pd.concat([POD,JMCAll])


new_df.reset_index(inplace=True)
new_df.drop(['index'],axis = 1, inplace=True)
new_df
new_df.to_csv("C:/Users/Lo/ArusData/POD.csv")
